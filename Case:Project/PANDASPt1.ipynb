# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "/Users/williampappas/Desktop/GitLab/02-Homework/04-Python-Pandas/03-Pandas-Project/Mini-Project-Part-1/Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
coder_data = pd.read_csv(file, encoding= 'iso-8859-1',low_memory=False)
coder_data.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Inspect all columns
coder_data.count()
# Out:
# Age                     13613
# AttendedBootcamp        15380
# BootcampFinish            933
# BootcampFullJobAfter      635
# BootcampLoanYesNo         934
#                         ...
# ResourceW3Schools         121
# ResourceYouTube           121
# SchoolDegree            13679
# SchoolMajor              8450
# StudentDebtOwe           3514
# Length: 113, dtype: int64

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
adjusted_coder = coder_data.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
adjusted_coder.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
adjusted_coder = adjusted_coder.replace({0.0: "No", 1.0: "Yes"})
adjusted_coder.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey
total_respondents = len(adjusted_coder)
total_respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attendance = adjusted_coder.loc[adjusted_coder["AttendedBootcamp"] == "Yes"]
attendance.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Calculate average age of attendees
average_age = attendance["Age"].mean()
# Calculate how many people attended a bootcamp
numattend = attendance["AttendedBootcamp"].count()
# Calculate how many attendees hold degrees
degrees = attendance["SchoolDegree"].count()
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
total_gender = attendance["Gender"].count()
male_gender = attendance["Gender"].value_counts()['male']
female_gender = attendance["Gender"].value_counts()['female']
non_gender = total_gender - male_gender - female_gender
# Calculate percentage of respondents who attended a bootcamp
percattend = round((numattend / total_respondents) * 100,2)
# Calculate percentage of respondents belonging to each gender
percmale = round((male_gender / total_gender) * 100,2)
percfemale = round((female_gender / total_gender) * 100,2)
percnon = round((non_gender / total_gender) * 100,2)
# Calculate percentage of attendees with a school degree
percdegree = round((degrees / numattend) * 100,2)
# Calculate average post-bootcamp salary
avgsalary = attendance["BootcampPostSalary"].mean()

# %%
# Create a new table consolodating above calculations
bootcamp_table = pd.DataFrame({"Total Surveyed": [total_respondents],
                              "Total Attendees": [numattend],
                              "Average Age Attended": [average_age],
                              "Attendance with Degrees": [degrees],
                               "Percent with Degree": [percdegree],
                              "Males Attended" : [male_gender],
                              "Male Percent": [percmale],
                              "Females Attended": [female_gender],
                              "Female Percent": [percfemale],
                              "Non Gender Attended": [non_gender],
                              "Non Gender Percent": [percnon],
                               "Average Post Salary": [avgsalary]
                              })
bootcamp_table = bootcamp_table[["Total Surveyed","Total Attendees","Average Age Attended","Attendance with Degrees","Percent with Degree","Males Attended","Male Percent","Females Attended","Female Percent","Non Gender Attended","Non Gender Percent","Average Post Salary"]]
bootcamp_table = bootcamp_table.round(2)

bootcamp_table
# Out:
#    Total Surveyed  Total Attendees  Average Age Attended  \
# 0           15620              953                 31.07
#
#    Attendance with Degrees  Percent with Degree  Males Attended  Male Percent  \
# 0                      832                 87.3             496         59.54
#
#    Females Attended  Female Percent  Non Gender Attended  Non Gender Percent  \
# 0               326           39.14                   11                1.32
#
#    Average Post Salary
# 0             63740.51

# %%
# Improve formatting before outputting spreadsheet
bootcamp_table["Percent with Degree"]=bootcamp_table["Percent with Degree"].map("{0:,.2f}%".format)
bootcamp_table["Male Percent"]=bootcamp_table["Male Percent"].map("{0:,.2f}%".format)
bootcamp_table["Female Percent"]=bootcamp_table["Female Percent"].map("{0:,.2f}%".format)
bootcamp_table["Non Gender Percent"]=bootcamp_table["Non Gender Percent"].map("{0:,.2f}%".format)
bootcamp_table["Average Post Salary"]=bootcamp_table["Average Post Salary"].map("{0:,.2f}$".format)
bootcamp_table
# Out:
#    Total Surveyed  Total Attendees  Average Age Attended  \
# 0           15620              953                 31.07
#
#    Attendance with Degrees Percent with Degree  Males Attended Male Percent  \
# 0                      832              87.30%             496       59.54%
#
#    Females Attended Female Percent  Non Gender Attended Non Gender Percent  \
# 0               326         39.14%                   11              1.32%
#
#   Average Post Salary
# 0          63,740.51$

# %%
pwd
# Out:
# '/Users/williampappas/Desktop/GitLab/02-Homework/04-Python-Pandas/03-Pandas-Project/Mini-Project-Part-1'

# %%
# Export to Excel
bootcamp_table.to_excel("/Users/williampappas/Desktop/PANDASPt1.xlsx", index=False)
